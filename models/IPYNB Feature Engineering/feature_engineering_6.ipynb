# %%
import pandas as pd
import numpy as np

# %%
titanic = pd.read_csv('../datasets/titanic_transformed.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_clean Embarked_clean  \
# 0      0         A/5 21171   7.2500   NaN        S       22.0              S
# 1      0          PC 17599  71.2833   C85        C       38.0              C
# 2      0  STON/O2. 3101282   7.9250   NaN        S       26.0              S
# ...

# %%
# create title feature
titanic["Title"] = titanic['Name'].apply(lambda x: x.split(',')[1].split('.')[0].strip())
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_clean Embarked_clean  \
# 0      0         A/5 21171   7.2500   NaN        S       22.0              S
# 1      0          PC 17599  71.2833   C85        C       38.0              C
# 2      0  STON/O2. 3101282   7.9250   NaN        S       26.0              S
# ...

# %%
# look at the survival rate by title
titanic.pivot_table('Survived', index=['Title', 'Sex'], aggfunc=['count', 'mean'])
# Out:
#                        count      mean
#                     Survived  Survived
# Title        Sex
# Capt         male          1  0.000000
# Col          male          2  0.500000
# Don          male          1  0.000000
# Dr           female        1  1.000000
#              male          6  0.333333
# Jonkheer     male          1  0.000000
# Lady         female        1  1.000000
# Major        male          2  0.500000
# Master       male         40  0.575000
# Miss         female      182  0.697802
# Mlle         female        2  1.000000
# Mme          female        1  1.000000
# Mr           male        517  0.156673
# Mrs          female      125  0.792000
# Ms           female        1  1.000000
# Rev          male          6  0.000000
# Sir          male          1  1.000000
# the Countess female        1  1.000000

# %%
titanic.to_csv('../datasets/titanic_title.csv', index=False)

# %%
titanic = pd.read_csv('../datasets/titanic_title.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_clean Embarked_clean  \
# 0      0         A/5 21171   7.2500   NaN        S       22.0              S
# 1      0          PC 17599  71.2833   C85        C       38.0              C
# 2      0  STON/O2. 3101282   7.9250   NaN        S       26.0              S
# ...

# %%
# what would an indicator variable for cabin look like
titanic.groupby(titanic['Cabin'].isnull())['Survived'].mean()
# Out:
# Cabin
# False    0.666667
# True     0.299854
# Name: Survived, dtype: float64

# %%
# create indicator feature 
titanic['Cabin_ind'] = np.where(titanic['Cabin'].isnull(),0,1)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_clean Embarked_clean  \
# 0      0         A/5 21171   7.2500   NaN        S       22.0              S
# 1      0          PC 17599  71.2833   C85        C       38.0              C
# 2      0  STON/O2. 3101282   7.9250   NaN        S       26.0              S
# ...

# %%
titanic.head()
titanic.to_csv('../datasets/titanic_cabin_ind.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
titanic['Family_cnt'] = titanic['SibSp'] + titanic['Parch']
sns.catplot(x='Family_cnt', y='Survived', data=titanic, kind='point', aspect=2)
plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_clean Embarked_clean  \
# 0      0         A/5 21171   7.2500   NaN        S       22.0              S
# 1      0          PC 17599  71.2833   C85        C       38.0              C
# 2      0  STON/O2. 3101282   7.9250   NaN        S       26.0              S
# ...

# %%
titanic.to_csv('../datasets/titanic_family_cnt.csv', index=False)

# %%
titanic = pd.read_csv('../datasets/titanic_family_cnt.csv')
titanic.head()
from sklearn.preprocessing import LabelEncoder

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_clean Embarked_clean  \
# 0      0         A/5 21171   7.2500   NaN        S       22.0              S
# 1      0          PC 17599  71.2833   C85        C       38.0              C
# 2      0  STON/O2. 3101282   7.9250   NaN        S       26.0              S
# ...

# %%
# Convert categorical features to numeric levels
for feature in ['Sex', 'Cabin', 'Embarked', 'Embarked_clean', 'Title']:
    le = LabelEncoder()
    titanic[feature] = le.fit_transform(titanic[feature].astype(str))
    
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare  Cabin  Embarked  Age_clean  Embarked_clean  \
# 0         A/5 21171   7.2500    147         2       22.0               3
# 1          PC 17599  71.2833     81         0       38.0               0
# ...

# %%
titanic.to_csv('../datasets/titanic_numeric.csv')
